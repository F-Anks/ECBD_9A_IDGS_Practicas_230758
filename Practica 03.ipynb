# %% [markdown]
# # Practica 03: Analisis de Datos Exploratorio de Python y Jupiter Notebook

# %% [markdown]
# **Programa de Estudios:** Ingieneria en Desarrollo y Gestion de Software \
# **Asignatura:** Extraccion conocimientos en bases de datos\
# **Docente:** M.T.I. Marco A. Ramirez Hernandez\
# **Periodo:** Mayo-Agosto 2026
#
# **Nombre del Estudiante:** Francisco Garcia Garcia\
# **Matricula:** 230758\
# **Grado y Grupo:** 9° "A" IDGS

# %% [markdown]
# El estudiante practicara como realizar un analisis exploratorio de datos, utilizando el lenguaje de programacion de Python, y librerias comunes para la carga, manipulacion, analisis y visualizacion previa de un conjunto de datos (Dataset), para esta practica se utilizaran las librerias de:
# - Pandas
# - Numpy
# - Seaborn
# - os
# - Matplotlib

# %% [markdown]
# 1. importar las librerias necesarias para realizar el EDA
# Comenzamos por importar la libreria que nos permita manipular los datos del dataset extraidos de una fuente de datos (datasource)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# 2. Creamos un DataFrame leyendo el archivo delimitado por comas (CSV)

# %%
pokemons=pd.read_csv('./Pokemon.csv')

# %% [markdown]
# 3. Imprimimos el resultado de la lectura
# Este comando imprime en una tabla las columnas y las filas del dataframe, siempre de manera eestandar nos mostrara los primero 5 y los 5 registros del dataframe

# %%
pokemons
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# 4. Obtenemos una muestra aleatoria de resgistros del dataframe usando el metodo sample
# Como parametro de entrada podemos definir un entero que determina el tamaño de la muestra

# %%
pokemons.sample(6)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 481  433              Chingling  Psychic       NaN    285   45      30
# 412  376              Metagross    Steel   Psychic    600   80     135
# 679  618               Stunfisk   Ground  Electric    471  109      66
# 544  487  GiratinaAltered Forme    Ghost    Dragon    680  150     100
# 761  691               Dragalge   Poison    Dragon    494   65      75
# 148  137                Porygon   Normal       NaN    395   65      60
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 481       50       65       50     45           4      False
# 412      130       95       90     70           3      False
# 679       84       81       99     32           5      False
# 544      120      100      120     90           4       True
# 761       90       97      123     44           6      False
# 148       70       85       75     40           1      False

# %% [markdown]
# ## Ejercicio 1: Obten una muestra de 50 pokemones
#
# 5. Obtener una muestra de rangos definidos usando **.iloc**

# %%
pokemones_100_to_200 = pokemons.iloc[100:200]
pokemones_100_to_200
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 100   93                Haunter     Ghost  Poison    405   45      50
# 101   94                 Gengar     Ghost  Poison    500   60      65
# 102   94      GengarMega Gengar     Ghost  Poison    600   60      65
# 103   95                   Onix      Rock  Ground    385   35      45
# 104   96                Drowzee   Psychic     NaN    328   60      48
# ..   ...                    ...       ...     ...    ...  ...     ...
# 195  181               Ampharos  Electric     NaN    510   90      75
# 196  181  AmpharosMega Ampharos  Electric  Dragon    610   90      95
# 197  182              Bellossom     Grass     NaN    490   75      80
# 198  183                 Marill     Water   Fairy    250   70      20
# 199  184              Azumarill     Water   Fairy    420  100      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 100       45      115       55     95           1      False
# ...

# %% [markdown]
# 6. Como saber las columnas o atributos tien el data frame

# %%
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Campo   Descripción
# **#**:  El ID o número de identificación del Pokémon. \
# **Name**:   El nombre del Pokémon.\
# **Type 1**: Se refiere a las propiedades elementales (tipos) asociadas tanto al Pokémon como a sus movimientos.\
# **Type 2**: Los Pokémon pueden tener hasta dos tipos (Pokémon de tipo dual); los movimientos solo pueden tener uno.\
# **Total**:  Representa la suma de todos los stats, lo que te da una idea de qué tan "pesado" o fuerte es el Pokémon.\
# **HP**: (Puntos de Salud) Es qué tanto aguante tiene un Pokémon antes de que lo dejen fuera de combate (se desmaye).\
# **Attack**: La fuerza de los ataques físicos del Pokémon.\
# **Defense**:    Qué tanto aguanta el Pokémon contra los ataques físicos del rival.\
# **Sp. Atk**:    Ataque Especial; el poder de los movimientos especiales del Pokémon.\
# **Sp. Def**:    Defensa Especial; qué tan resistente es el Pokémon ante los ataques especiales.\
# **Speed**:  Velocidad; el Pokémon que tenga más velocidad es el que ataca primero.\
# **Generation**: Se refiere a la generación de la serie de juegos a la que pertenece.\
# **Legendary**:  Indica si el Pokémon es Legendario o no (son bichos muy raros y poderosos). Es un valor booleano (sí/no).

# %% [markdown]
# 7.- Explorar la composición y ausencia de datos (METADATA) con **.info**
#     La libreria de pandas incluye un metodo que nos permite evaluar el tipo de datos, su composicion y ausencia

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# 8.- Limpieza de datos

# %% [markdown]
# Dependiendo del objetivo del analisis algunas columnas o registros no seran necesarias en nuestro dataframe en este caso omitiremos los datos vacios
# eliminaremos la comlumna 'type 2' , y renombremos la columna por 'type 1' por 'type'

# %%
pokemons = pokemons.drop(columns=['type 2']).rename(columns={'type 1': 'type'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pokemons = pokemons.drop(columns=['type 2']).rename(columns={'type 1': 'type'})
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %% [markdown]
# **EJERCICIO 2:** Consulta la METADATA de la actualizacion y compara los cambios con la anterior
#
# ¿que datos ves?, redacta tu respuesta

# %% [markdown]
# 9.- Visualizacion de los primeros datos usando del metodo:  **.head**

# %%
pokemons.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# **Ejercicio 3:** Muestra los ultimos 10 registros del dataframe

# %%
pokemons.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# ...

# %% [markdown]
# 10.-

# %%
pokemons.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# 11.- Calcular el total de datos no duplicados (unicos)

# %% [markdown]
# Usaremos .len() como función para calcular la longitud del dataframe y .unique() para excluir los duplicados
#
# **NOTA:** No considerar ID como un atributo de llave primaria , sino el total de columnas como un solo elemento u objeto.
#
# Obteniendo los valores unicos por columna en este caso en la columna "Name"

# %%
len(pokemons.Name.unique())
# Out:
# 800

# %% [markdown]
# Obteniento el total de objetos (conjunto de atributos, estrictamente iguales) unicos.

# %%
total_unicos = len(pokemons.drop_duplicates())
total_unicos
# Out:
# 800

# %% [markdown]
# **Ejercicio 04:** Obtener el total de IDs unicos en el dataset

# %%
len(pokemons['#'].unique())
# Out:
# 721

# %% [markdown]
# **Ejercicio 05:** Obtener el total de tipos unicos de pokemones

# %%
len(pokemons['Type 1'].unique())
# Out:
# 18

# %%
pokemons['Generation'].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
sns.countplot(x='Generation', data=pokemons, palette='nipy_spectral', hue='Generation', legend=False)
plt.title('Number of pokemons grouped by generation')
# Out:
# Text(0.5, 1.0, 'Number of pokemons grouped by generation')

# %%
pokemons ['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=pokemons, x='Type 1', palette='twilight', hue='Type 1', legend=False)
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=pokemons.drop(['#','Total','Generation','Legendary'],axis=1),fliersize=3,palette='seismic')
plt.title('Boxplots for stats')
# Out:
# Text(0.5, 1.0, 'Boxplots for stats')

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=pokemons.drop(['#','Total','Generation','Legendary'],axis=1),palette='rocket')
plt.title('Violinplots for stats')
# Out:
# Text(0.5, 1.0, 'Violinplots for stats')

# %%
pokemons.groupby('Type 1').sum(numeric_only=True)
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Dark      14302  13818  2071    2740     2177     2314     2155   2361
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Fairy      7642   7024  1260    1046     1117     1335     1440    826
# Fighting   9824  11244  1886    2613     1780     1434     1747   1784
# Fire      17025  23820  3635    4408     3524     4627     3755   3871
# Flying     2711   1940   283     315      265      377      290    410
# Ghost     15568  14066  2062    2361     2598     2539     2447   2059
# Grass     24141  29480  4709    5125     4956     5425     4930   4335
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Ice       10165  10403  1728    1746     1714     1861     1831   1523
# ...

# %%
pokemons.groupby('Type 1')['HP'].sum()
# Out:
# Type 1
# Bug         3925
# Dark        2071
# Dragon      2666
# Electric    2631
# Fairy       1260
# Fighting    1886
# Fire        3635
# Flying       283
# Ghost       2062
# Grass       4709
# Ground      2361
# Ice         1728
# Normal      7573
# Poison      1883
# Psychic     4026
# Rock        2876
# Steel       1761
# Water       8071
# Name: HP, dtype: int64

# %%
pokemons['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
list_types=pokemons['Type 1'].unique().tolist() 
list_types.sort()
list_types
# Out:
# ['Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water']

# %%
plt.style.use('ggplot')
plt.style.use('seaborn-darkgrid')

stats=pokemons[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']]
k=1
m=0
palette=['magma','ocean','vlag','copper','mako','winter']
plt.figure(figsize=(17,17))
for i in stats:
    plt.subplot(3,2,k)
    k=k+1
    sns.barplot(x=pokemons.groupby('Type').sum()[i],y=list_types,palette=palette[m])
    m=m+1
    plt.title(str('Total of '+i))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# ...
